# %%
# !wget https://images.wagwalkingweb.com/media/daily_wag/blog_articles/hero/1685787498.877709/fun-facts-about-siberian-huskies-1.png
# Out:
# --2023-12-22 18:44:31--  https://images.wagwalkingweb.com/media/daily_wag/blog_articles/hero/1685787498.877709/fun-facts-about-siberian-huskies-1.png
# Resolving images.wagwalkingweb.com (images.wagwalkingweb.com)... 172.67.68.12, 104.26.14.23, 104.26.15.23, ...
# Connecting to images.wagwalkingweb.com (images.wagwalkingweb.com)|172.67.68.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32708 (32K) [image/jpeg]
# Saving to: ‘fun-facts-about-siberian-huskies-1.png’
#
# fun-facts-about-sib 100%[===================>]  31.94K  --.-KB/s    in 0s
#
# 2023-12-22 18:44:32 (121 MB/s) - ‘fun-facts-about-siberian-huskies-1.png’ saved [32708/32708]

# %%
# prompt: script that uploads an image from my computer, reads it using opencv imread, and displays it using imshow

import cv2

from google.colab.patches import cv2_imshow

image = cv2.imread("/content/fun-facts-about-siberian-huskies-1.png")
print(image.shape)
print()
print(image)
cv2_imshow(image)
# Out:
# (555, 832, 3)
#
# [[[ 33  37  42]
#   [ 33  37  42]
#   [ 33  37  42]
#   ...
#   [ 30  42  44]
#   [ 30  42  44]
#   [ 31  43  45]]
#
#  [[ 33  37  42]
#   [ 33  37  42]
#   [ 33  37  42]
#   ...
#   [ 30  42  44]
#   [ 30  42  44]
#   [ 31  43  45]]
#
#  [[ 34  38  43]
#   [ 34  38  43]
#   [ 34  38  43]
#   ...
#   [ 30  42  44]
#   [ 30  42  44]
#   [ 31  43  45]]
#
#  ...
#
#  [[ 79 102 128]
#   [ 80 103 129]
#   [ 82 105 131]
#   ...
#   [ 83  96 110]
#   [ 84  97 113]
#   [ 84  97 113]]
#
#  [[ 79 102 128]
#   [ 80 103 129]
#   [ 82 105 131]
#   ...
#   [ 83  96 110]
#   [ 84  97 113]
#   [ 84  97 113]]
#
#  [[ 79 102 128]
#   [ 80 103 129]
#   [ 82 105 131]
#   ...
#   [ 83  96 110]
#   [ 84  97 113]
#   [ 85  98 114]]]
# <PIL.Image.Image image mode=RGB size=832x555>
